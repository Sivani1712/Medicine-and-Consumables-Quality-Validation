# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("healthcare_dataset.csv")

# %%
df.head(10)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 0       Bobby JacksOn   30    Male         B-            Cancer
# 1        LesLie TErRy   62    Male         A+           Obesity
# 2         DaNnY sMitH   76  Female         A-           Obesity
# 3        andrEw waTtS   28  Female         O+          Diabetes
# 4       adrIENNE bEll   43  Female        AB+            Cancer
# 5       EMILY JOHNSOn   36    Male         A+            Asthma
# 6      edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7  CHrisTInA MARtinez   20  Female         A+            Cancer
# 8     JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9    ChRISTopher BerG   58  Female        AB-            Cancer
#
#   Date of Admission            Doctor                     Hospital  \
# 0        2024-01-31     Matthew Smith              Sons and Miller
# 1        2019-08-20   Samantha Davies                      Kim Inc
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df["Medication"].value_counts()
# Out:
# Medication
# Lipitor        11140
# Ibuprofen      11127
# Aspirin        11094
# Paracetamol    11071
# Penicillin     11068
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df= df.drop(['Name','Date of Admission','Doctor', 'Hospital', 'Insurance Provider','Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date'],axis='columns')

# %%
df.head()
# Out:
#    Age  Gender Blood Type Medical Condition   Medication  Test Results
# 0   30    Male         B-            Cancer  Paracetamol        Normal
# 1   62    Male         A+           Obesity    Ibuprofen  Inconclusive
# 2   76  Female         A-           Obesity      Aspirin        Normal
# 3   28  Female         O+          Diabetes    Ibuprofen      Abnormal
# 4   43  Female        AB+            Cancer   Penicillin      Abnormal

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Blood Type           0
# Medical Condition    0
# Medication           0
# Test Results         0
# dtype: int64

# %%
df.shape
# Out:
# (55500, 6)

# %%
df["Age"].describe()
# Out:
# count    55500.000000
# mean        51.539459
# std         19.602454
# min         13.000000
# 25%         35.000000
# 50%         52.000000
# 75%         68.000000
# max         89.000000
# Name: Age, dtype: float64

# %%
df["Age"].value_counts()
# Out:
# Age
# 38    897
# 37    893
# 57    887
# 80    864
# 34    864
#      ...
# 88     25
# 16     24
# 14     18
# 13     14
# 89      8
# Name: count, Length: 77, dtype: int64

# %%
len(df[df["Age"]<20])
# Out:
# 1693

# %%
len(df[df["Test Results"]=="Inconclusive"])
# Out:
# 18356

# %%
sns.boxplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
df["Age"].unique()
# Out:
# array([30, 62, 76, 28, 43, 36, 21, 20, 82, 58, 72, 38, 75, 68, 44, 46, 63,
#        34, 67, 48, 59, 73, 51, 23, 78, 25, 33, 26, 70, 57, 74, 81, 49, 65,
#        31, 22, 77, 42, 24, 84, 55, 40, 83, 18, 27, 19, 29, 61, 80, 60, 35,
#        79, 53, 69, 47, 85, 52, 37, 50, 32, 54, 45, 66, 39, 56, 64, 71, 41,
#        88, 17, 87, 86, 15, 16, 13, 14, 89], dtype=int64)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      27774
# Female    27726
# Name: count, dtype: int64

# %%
df["Blood Type"].value_counts()
# Out:
# Blood Type
# A-     6969
# A+     6956
# AB+    6947
# AB-    6945
# B+     6945
# B-     6944
# O+     6917
# O-     6877
# Name: count, dtype: int64

# %%
df["Medical Condition"].value_counts()
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
df["Medication"].value_counts()
# Out:
# Medication
# Lipitor        11140
# Ibuprofen      11127
# Aspirin        11094
# Paracetamol    11071
# Penicillin     11068
# Name: count, dtype: int64

# %%
df["Test Results"].value_counts()
# Out:
# Test Results
# Abnormal        18627
# Normal          18517
# Inconclusive    18356
# Name: count, dtype: int64

# %%
df.replace({"Gender":{"Male":0,"Female":1}},inplace=True)
# Out:
# C:\Users\Sivani\AppData\Local\Temp\ipykernel_8416\1450194634.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"Gender":{"Male":0,"Female":1}},inplace=True)

# %%
en_bt={"A-":1,"A+":2,"AB+":3,"AB-":4,"B+":5,"B-":6,"O+":7,"O-":8}

# %%
df["Blood Type"]=df["Blood Type"].map(en_bt)

# %%
df.head()
# Out:
#    Age  Gender  Blood Type Medical Condition   Medication  Test Results
# 0   30       0           6            Cancer  Paracetamol        Normal
# 1   62       0           2           Obesity    Ibuprofen  Inconclusive
# 2   76       1           1           Obesity      Aspirin        Normal
# 3   28       1           7          Diabetes    Ibuprofen      Abnormal
# 4   43       1           3            Cancer   Penicillin      Abnormal

# %%
en_mc={"Arthritis":1,"Diabetes":2,"Hypertension":3,"Obesity":4,"Cancer":5,"Asthma":6}

# %%
df["Medical Condition"]=df["Medical Condition"].map(en_mc)

# %%
df.head()
# Out:
#    Age  Gender  Blood Type  Medical Condition   Medication  Test Results
# 0   30       0           6                  5  Paracetamol        Normal
# 1   62       0           2                  4    Ibuprofen  Inconclusive
# 2   76       1           1                  4      Aspirin        Normal
# 3   28       1           7                  2    Ibuprofen      Abnormal
# 4   43       1           3                  5   Penicillin      Abnormal

# %%
en_med={"Lipitor":1,"Ibuprofen":2,"Aspirin":3,"Paracetamol":4,"Penicillin":5}

# %%
df["Medication"]=df["Medication"].map(en_med)

# %%
df.head()
# Out:
#    Age  Gender  Blood Type  Medical Condition  Medication  Test Results
# 0   30       0           6                  5           4        Normal
# 1   62       0           2                  4           2  Inconclusive
# 2   76       1           1                  4           3        Normal
# 3   28       1           7                  2           2      Abnormal
# 4   43       1           3                  5           5      Abnormal

# %%
sns.pairplot(df,hue="Test Results")

# %%
sns.scatterplot(x="Medical Condition",y="Test Results",data=df)
# Out:
# <Axes: xlabel='Medical Condition', ylabel='Test Results'>

# %%
df1=df[~(df["Test Results"]=="Inconclusive")]

# %%
df1.head(10)
# Out:
#     Age  Gender  Blood Type  Medical Condition  Medication Test Results
# 0    30       0           6                  5           4       Normal
# 2    76       1           1                  4           3       Normal
# 3    28       1           7                  2           2     Abnormal
# 4    43       1           3                  5           5     Abnormal
# 5    36       0           2                  6           2       Normal
# 8    82       0           3                  6           3     Abnormal
# 10   72       0           7                  5           4       Normal
# 12   75       1           2                  2           5     Abnormal
# 13   68       1           3                  6           1       Normal
# 14   44       1           3                  5           4       Normal

# %%
df1["Test Results"].unique()
# Out:
# array(['Normal', 'Abnormal'], dtype=object)

# %%
df1.shape
# Out:
# (37144, 6)

# %%
df2=df1[df1['Age']>35]

# %%
d3=df2[df2["Age"]<68]

# %%
d3.shape
# Out:
# (17584, 6)

# %%
sns.histplot(x=d3["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
x=df.iloc[:,:-1]
x.columns
# Out:
# Index(['Age', 'Gender', 'Blood Type', 'Medical Condition', 'Medication'], dtype='object')

# %%
y=df["Test Results"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=104,  test_size=0.3,)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((38850, 5), (16650, 5), (38850,), (16650,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(multi_class="multinomial")

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\Sivani\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\Sivani\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(multi_class='multinomial')

# %%
lr.score(x_test,y_test)*100
# Out:
# 33.291291291291294

# %%
x1=d3.iloc[:,:-1]
x.columns
# Out:
# Index(['Age', 'Gender', 'Blood Type', 'Medical Condition', 'Medication'], dtype='object')

# %%
y1=d3["Test Results"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,random_state=104,  test_size=0.3,)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((12308, 5), (5276, 5), (12308,), (5276,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(multi_class="multinomial")

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\Sivani\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1237: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, binary problems will be fit as proper binary  logistic regression models (as if multi_class='ovr' were set). Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='multinomial')

# %%
lr.score(x_test,y_test)*100
# Out:
# 50.701288855193326
